# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\tmax_\Downloads\averysmusic.csv")
df
# Out:
#            endTime                                         artistName  \
# 0     9/2/20 15:26  The Gilded Playlist - An Indie Music Recommend...
# 1     9/2/20 15:26  The Gilded Playlist - An Indie Music Recommend...
# 2     1/9/21 20:06                                 Binge Mode: Marvel
# 3     3/10/21 1:14                                           Big Sean
# 4     3/10/21 1:14                                        Jack Harlow
# ..             ...                                                ...
# 340  7/31/21 19:31  BFFs featuring Josh Richards and Dave Portnoy ...
# 341  7/31/21 20:31  BFFs featuring Josh Richards and Dave Portnoy ...
# 342  7/31/21 22:00  BFFs featuring Josh Richards and Dave Portnoy ...
# 343  7/31/21 23:07                                The Ringer NBA Show
# 344    8/1/21 7:21                                         First Take
#
#                                              trackName  msPlayed
# ...

# %%
df.to_excel(r"C:\Users\tmax_\Downloads\averysmusic.xlsx", index = None, header = True)

# %% [markdown]
# df.info()

# %%
df['endTime'].str.strip()
df[['Date','Time']] = df['endTime'].str.split(' ',1, expand = True)
df
# Out:
# C:\Users\tmax_\AppData\Local\Temp\ipykernel_16024\3482516311.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Date','Time']] = df['endTime'].str.split(' ',1, expand = True)
#            endTime                                         artistName  \
# 0     9/2/20 15:26  The Gilded Playlist - An Indie Music Recommend...
# 1     9/2/20 15:26  The Gilded Playlist - An Indie Music Recommend...
# 2     1/9/21 20:06                                 Binge Mode: Marvel
# 3     3/10/21 1:14                                           Big Sean
# 4     3/10/21 1:14                                        Jack Harlow
# ..             ...                                                ...
# 340  7/31/21 19:31  BFFs featuring Josh Richards and Dave Portnoy ...
# 341  7/31/21 20:31  BFFs featuring Josh Richards and Dave Portnoy ...
# 342  7/31/21 22:00  BFFs featuring Josh Richards and Dave Portnoy ...
# ...

# %%
df.nunique()
# Out:
# endTime       321
# artistName     68
# trackName     204
# msPlayed      340
# Date           64
# Time          279
# dtype: int64

# %%
df_sorted.to_excel(r"C:\Users\tmax_\Downloads\averysmusic_sorted2.xlsx", index = None, header = True)

# %%
df_sorted = df.sort_values(by = "artistName")
df_sorted
# Out:
#            endTime                     artistName  \
# 5     3/10/21 1:15                          Aminé
# 88   5/15/21 14:43  An Oral History of The Office
# 87   5/15/21 14:22  An Oral History of The Office
# 86   5/15/21 14:12  An Oral History of The Office
# 85    5/15/21 5:18  An Oral History of The Office
# ..             ...                            ...
# 244   7/18/21 5:39    Wait Wait... Don't Tell Me!
# 245   7/18/21 6:30    Wait Wait... Don't Tell Me!
# 36     5/9/21 0:40    Wait Wait... Don't Tell Me!
# 93   5/15/21 18:23               You Inc. Podcast
# 94    5/16/21 2:27               You Inc. Podcast
#
#                                              trackName  msPlayed     Date  \
# 5                                           Spice Girl      8960  3/10/21
# 88                       12. Beauty in Ordinary Things    706185  5/15/21
# 87                       12. Beauty in Ordinary Things    530899  5/15/21
# ...

# %%
df
# Out:
#            endTime                                         artistName  \
# 0     9/2/20 15:26  The Gilded Playlist - An Indie Music Recommend...
# 1     9/2/20 15:26  The Gilded Playlist - An Indie Music Recommend...
# 2     1/9/21 20:06                                 Binge Mode: Marvel
# 3     3/10/21 1:14                                           Big Sean
# 4     3/10/21 1:14                                        Jack Harlow
# ..             ...                                                ...
# 340  7/31/21 19:31  BFFs featuring Josh Richards and Dave Portnoy ...
# 341  7/31/21 20:31  BFFs featuring Josh Richards and Dave Portnoy ...
# 342  7/31/21 22:00  BFFs featuring Josh Richards and Dave Portnoy ...
# 343  7/31/21 23:07                                The Ringer NBA Show
# 344    8/1/21 7:21                                         First Take
#
#                                              trackName  msPlayed     Date  \
# ...

# %%
df_sorted
# Out:
#            endTime                            artistName  \
# 94    5/16/21 2:27                      You Inc. Podcast
# 93   5/15/21 18:23                      You Inc. Podcast
# 35     5/8/21 5:28           Wait Wait... Don't Tell Me!
# 244   7/18/21 5:39           Wait Wait... Don't Tell Me!
# 245   7/18/21 6:30           Wait Wait... Don't Tell Me!
# 36     5/9/21 0:40           Wait Wait... Don't Tell Me!
# 97   5/16/21 10:03           Wait Wait... Don't Tell Me!
# 96    5/16/21 7:52           Wait Wait... Don't Tell Me!
# 95    5/16/21 6:25           Wait Wait... Don't Tell Me!
# 89   5/15/21 17:37  VIEWS with David Dobrik & Jason Nash
#
#                                              trackName  msPlayed     Date  \
# 94   009 - Leah McHenry "How to become a Kajabi Mil...   1059968  5/16/21
# 93   009 - Leah McHenry "How to become a Kajabi Mil...    787314  5/15/21
# 35      Tariq Trotter AKA Black Thought from The Roots     22500   5/8/21
# ...

# %%
df_time = df.groupby('Time').mean()
# Out:
# C:\Users\tmax_\AppData\Local\Temp\ipykernel_16024\200672446.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_time = df.groupby('Time').mean()

# %% [markdown]
#     Organized the excel into differnt groups to make the visuals i want easier to remember.

# %%
sum_top_audios = df.groupby('trackName').sum().sort_values(by = "msPlayed", ascending = False)
# Out:
# C:\Users\tmax_\AppData\Local\Temp\ipykernel_16024\2382533386.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sum_top_audios = df.groupby('trackName').sum().sort_values(by = "msPlayed", ascending = False)

# %%
sum_top_audios.to_excel(r"C:\Users\tmax_\Downloads\averysmusic_sum_top_audios.xlsx", index = True, header = True)

# %%
sum_TopAudios
# Out:
#                                                     msPlayed
# trackName
# #1600 - Lex Fridman                                 11493625
# #1620 - Nate Bargatze                               11312229
# Team USA's Olympic Chances, Dame's Future, Can ...  10175785
# All-NBA Arguments, Milwaukee’s Best, CP3 Ground...   8301056
# A Bucks-Hawks Blahfest, CP3’s Legacy Run, NBA A...   6664896
# ...                                                      ...
# Leave Before You Love Me (with Jonas Brothers)          1834
# Heat Waves                                              1386
# Don't Go Yet                                            1280
# NDA                                                     1237
# Peaches (feat. Daniel Caesar & Giveon)                   618
#
# [204 rows x 1 columns]

# %%
df_time.to_excel(r"C:\Users\tmax_\Downloads\averysmusic_df_time.xlsx", index = True, header = True)
